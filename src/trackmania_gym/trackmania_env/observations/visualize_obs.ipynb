# %%
from matplotlib import pyplot as plt
import numpy as np
# %cd ..
# %cd ..

# %%
load_idx = 270
raw_img : np.ndarray= np.load(f"logs/observations/raw_image_{load_idx}.npy")
processed_img : np.ndarray = np.load(f"logs/observations/processed_image_{load_idx}.npy")

# %%
print(raw_img.shape)
plt.imshow(raw_img)

# %%
print(processed_img.shape)
plt.imshow(processed_img.squeeze(0))

# %%
plt.imshow(processed_img[:, 40:100].squeeze())
